# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import tensorflow as tf
from tensorflow import keras

# %% [markdown]
# ### **Set Constants**

# %%
EPOCHS = 50
IMAGE_SIZE = (128, 128)
INPUT_SHAPE = (128, 128, 3)
# DATASET_DIR = "/kaggle/input/sugarcane-leaf-disease-dataset"
SEED = 123
BATCH_SIZE = 64
BUFFER_SIZE = 350
FINE_TUNE_POINT = 100
LEARNING_RATE = 0.001

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
DATASET_DIR = '../data/arcgis-survey-images-new'

# %% [markdown]
# ### **Load Image Datasets**

# %%
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    DATASET_DIR,
    labels="inferred",
    batch_size=BATCH_SIZE,
    image_size=IMAGE_SIZE,
    shuffle=True,
    seed=SEED,
    validation_split=0.2,
    subset="training"
)

validation_ds = tf.keras.preprocessing.image_dataset_from_directory(
    DATASET_DIR,
    labels="inferred",
    batch_size=BATCH_SIZE,
    image_size=IMAGE_SIZE,
    seed=SEED,
    validation_split=0.2,
    subset="validation"
)
# Out:
# Found 3757 files belonging to 5 classes.
# Using 3006 files for training.
# Found 3757 files belonging to 5 classes.
# Using 751 files for validation.

# %%
data_augmentation = tf.keras.Sequential([
    tf.keras.layers.RandomFlip('horizontal_and_vertical'),
    tf.keras.layers.RandomRotation(0.2),
    tf.keras.layers.RandomZoom(0.1),
    tf.keras.layers.RandomContrast(0.1),
])

augmented_train_ds = train_ds.map(
    lambda x, y: (data_augmentation(x, training=True), y))

# %%
class_names = train_ds.class_names

# %%
for example_image, example_label in train_ds.take(1):
  break

print(f"Image Shape: {example_image.shape}")
# Out:
# Image Shape: (64, 128, 128, 3)

# %% [markdown]
# ### **Split Validation Dataset into a Validation DS and Test DS**

# %%
validation_ds = validation_ds.shard(num_shards=2, index=0)
test_ds = validation_ds.shard(num_shards=2, index=1)

# %% [markdown]
# ### **Visualize a Set of Training Data**

# %%
plt.figure(figsize=(12, 9))
for images, labels in train_ds.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(class_names[labels[i]])
        plt.suptitle("Sugarcane Leafs (Healthy or Diseased)")
        plt.axis("off")

# %%
train_ds = train_ds.cache().shuffle(BUFFER_SIZE).prefetch(buffer_size=tf.data.AUTOTUNE)
validation_ds = validation_ds.cache().prefetch(buffer_size=tf.data.AUTOTUNE)
test_ds = test_ds.cache().prefetch(buffer_size=tf.data.AUTOTUNE)

# %% [markdown]
# ### **Load Base Model**

# %%
from tensorflow.keras.applications import MobileNetV2

# Carga del modelo base con MobileNetV2
base_model = MobileNetV2(input_shape=INPUT_SHAPE,
                         include_top=False,
                         weights='imagenet')

# Ajuste de las capas del modelo base
for layer in base_model.layers[:100]:  # Ajusta el número de capas descongeladas
    layer.trainable = False

# Definir el modelo completo con capas adicionales
model = tf.keras.models.Sequential([
    tf.keras.layers.Rescaling(1./255),
    base_model,
    tf.keras.layers.GlobalAveragePooling2D(),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(64, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.01)),
    tf.keras.layers.Dropout(0.25),
    tf.keras.layers.Dense(len(class_names))
])

# Compilar el modelo
initial_learning_rate = 0.001
lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate,
    decay_steps=10000,
    decay_rate=0.9,
    staircase=True)

model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=lr_schedule),
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
for layer in base_model.layers[:FINE_TUNE_POINT]:
  layer.trainable = False

# %% [markdown]
# ### **Create the Classification Model**

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Rescaling(1./255),
    base_model,
    tf.keras.layers.GlobalAveragePooling2D(),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dropout(0.25),
    tf.keras.layers.Dense(len(class_names))
])

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=LEARNING_RATE),
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=['accuracy']
)

# %% [markdown]
# ### **Fit the Model**

# %%
history = model.fit(
    train_ds,
    validation_data=validation_ds,
    epochs=EPOCHS,
)
# Out:
# Epoch 1/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 39s 548ms/step - accuracy: 0.6424 - loss: 0.9775 - val_accuracy: 0.6406 - val_loss: 1.2571
# Epoch 2/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 23s 489ms/step - accuracy: 0.8914 - loss: 0.3481 - val_accuracy: 0.5391 - val_loss: 2.0203
# Epoch 3/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 23s 489ms/step - accuracy: 0.9316 - loss: 0.2050 - val_accuracy: 0.4818 - val_loss: 2.1353
# Epoch 4/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 23s 488ms/step - accuracy: 0.9235 - loss: 0.1870 - val_accuracy: 0.5755 - val_loss: 2.4049
# Epoch 5/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 23s 487ms/step - accuracy: 0.9664 - loss: 0.1110 - val_accuracy: 0.6224 - val_loss: 1.8318
# Epoch 6/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━
50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 24s 519ms/step - accuracy: 0.9949 - loss: 0.0157 - val_accuracy: 0.6797 - val_loss: 2.6729
# Epoch 32/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 23s 500ms/step - accuracy: 0.9843 - loss: 0.0385 - val_accuracy: 0.6536 - val_loss: 2.6510
# Epoch 33/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 22s 479ms/step - accuracy: 0.9955 - loss: 0.0131 - val_accuracy: 0.7083 - val_loss: 2.3975
# Epoch 34/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 22s 478ms/step - accuracy: 0.9991 - loss: 0.0021 - val_accuracy: 0.7422 - val_loss: 2.1397
# Epoch 35/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 23s 482ms/step - accuracy: 1.0000 - loss: 2.0100e-04 - val_accuracy: 0.7734 - val_loss: 2.0003
# Epoch 36/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 22s 479ms/step - accuracy: 1.0000 - loss: 2.7805e-04 - val_accuracy: 0.7760 - val_loss: 1.9333
# Epoch 37/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 23s 480ms/step - accuracy: 1.0000 - loss: 1.3599e-04 - val_accuracy: 0.7917 - val_loss: 1.8478
# Epoch 38/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 23s 482ms/step - accuracy: 1.0000 - loss: 1.1443e-04 - val_accuracy: 0.8073 - val_loss: 1.7892
# Epoch 39/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 23s 481ms/step - accuracy: 1.0000 - loss: 1.7692e-04 - val_accuracy: 0.8281 - val_loss: 1.7331
# Epoch 40/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 23s 481ms/step - accuracy: 1.0000 - loss: 1.5867e-04 - val_accuracy: 0.8411 - val_loss: 1.6971
# Epoch 41/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 23s 480ms/step - accuracy: 1.0000 - loss: 9.3505e-05 - val_accuracy: 0.8438 - val_loss: 1.6678
# Epoch 42/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 22s 479ms/step - accuracy: 1.0000 - loss: 9.7485e-05 - val_accuracy: 0.8464 - val_loss: 1.6389
# Epoch 43/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 23s 481ms/step - accuracy: 1.0000 - loss: 5.2927e-05 - val_accuracy: 0.8516 - val_loss: 1.6102
# Epoch 44/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 23s 480ms/step - accuracy: 1.0000 - loss: 1.1983e-04 - val_accuracy: 0.8594 - val_loss: 1.5827
# Epoch 45/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 23s 482ms/step - accuracy: 1.0000 - loss: 3.5935e-05 - val_accuracy: 0.8620 - val_loss: 1.5644
# Epoch 46/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 23s 480ms/step - accuracy: 1.0000 - loss: 4.5251e-05 - val_accuracy: 0.8672 - val_loss: 1.5457
# Epoch 47/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 23s 483ms/step - accuracy: 1.0000 - loss: 4.8111e-05 - val_accuracy: 0.8698 - val_loss: 1.5287
# Epoch 48/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 23s 482ms/step - accuracy: 1.0000 - loss: 5.3969e-05 - val_accuracy: 0.8724 - val_loss: 1.5155
# Epoch 49/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 22s 479ms/step - accuracy: 1.0000 - loss: 5.3216e-05 - val_accuracy: 0.8724 - val_loss: 1.4973
# Epoch 50/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 23s 479ms/step - accuracy: 1.0000 - loss: 4.1667e-05 - val_accuracy: 0.8724 - val_loss: 1.4791

# %% [markdown]
# ### **Classification Report**

# %%
metrics = history.history
plt.figure(figsize=(16, 6))
plt.subplot(1, 2, 1)
plt.plot(history.epoch, metrics['loss'], metrics['val_loss'])
plt.legend(['training', 'validation'])
plt.ylim([0, max(plt.ylim())])
plt.ylabel('Loss')
plt.xlabel('Epoch')

plt.subplot(1, 2, 2)
plt.plot(history.epoch, metrics['accuracy'], metrics['val_accuracy'])
plt.legend(['training', 'validation'])
plt.ylim([0, 1])
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
# Out:
# Text(0.5, 0, 'Epoch')

# %%
model.evaluate(test_ds, return_dict=True)
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 280ms/step - accuracy: 0.8613 - loss: 1.3316
# {'accuracy': 0.875, 'loss': 1.2490460872650146}

# %%
# # Guardar el modelo completo en formato .keras
# model.save('ruta_donde_guardar_modelo/mi_modelo.keras')

# %%
y_pred = model.predict(test_ds)
y_pred = np.argmax(y_pred, axis=1)
y_true = np.concatenate([y for x, y in test_ds], axis=0)
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 291ms/step

# %%
confusion_mtx = tf.math.confusion_matrix(y_true, y_pred)
plt.figure(figsize=(10, 8))
sns.heatmap(confusion_mtx,
            xticklabels=class_names,
            yticklabels=class_names,
            annot=True, fmt='g')
plt.xlabel('Prediction')
plt.ylabel('Label')
plt.show()

# %%
# Evaluación del modelo y visualización de resultados

# Evaluar el modelo en el conjunto de test
test_results = model.evaluate(test_ds, return_dict=True)
print("Resultados de evaluación en test set:")
for metric, value in test_results.items():
    print(f"{metric}: {value:.4f}")

# Predicción de etiquetas en el conjunto de test
y_pred = model.predict(test_ds)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true = np.concatenate([y for x, y in test_ds], axis=0)

# Reporte de clasificación
from sklearn.metrics import classification_report
print("Reporte de clasificación:")
print(classification_report(y_true, y_pred_classes, target_names=class_names))

# Matriz de confusión
from sklearn.metrics import confusion_matrix
conf_matrix = confusion_matrix(y_true, y_pred_classes)

plt.figure(figsize=(10, 8))
sns.heatmap(conf_matrix, xticklabels=class_names, yticklabels=class_names, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Matriz de Confusión')
plt.show()

# Curvas ROC y AUC para cada clase
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import label_binarize

y_true_bin = label_binarize(y_true, classes=range(len(class_names)))
plt.figure(figsize=(10, 8))

for i in range(len(class_names)):
    fpr, tpr, _ = roc_curve(y_true_bin[:, i], y_pred[:, i])
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, label=f'Clase {class_names[i]} (AUC = {roc_auc:.2f})')

plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('Tasa de Falsos Positivos (FPR)')
plt.ylabel('Tasa de Verdaderos Positivos (TPR)')
plt.title('Curvas ROC')
plt.legend(loc="lower right")
plt.show()
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 275ms/step - accuracy: 0.8613 - loss: 1.3316
# Resultados de evaluación en test set:
# accuracy: 0.8750
# loss: 1.2490
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 264ms/step
# Reporte de clasificación:
#                   precision    recall  f1-score   support
#
# Chinche salivosa       0.93      0.91      0.92        44
#         Clororis       0.88      0.82      0.85        17
#        Hoja sana       0.93      0.93      0.93        46
#     Roya naranja       0.87      0.84      0.85        56
#     Roya purpura       0.73      0.83      0.77        29
#
#         accuracy                           0.88       192
#        macro avg       0.87      0.87      0.87       192
#     weighted avg       0.88      0.88      0.88       192

# %%
# Función para mostrar predicciones aleatorias
def show_predictions(model, dataset, num_images=5):
    random_indices = np.random.choice(len(dataset), num_images, replace=False)
    for i in random_indices:
        image, label = next(iter(dataset.skip(i).take(1)))
        pred = model.predict(image)
        plt.imshow(image[0].numpy().astype("uint8"))
        plt.title(f"Predicción: {class_names[np.argmax(pred)]}, Real: {class_names[label[0]]}")
        plt.axis('off')
        plt.show()

# Mostrar 5 predicciones aleatorias
show_predictions(model, validation_ds, num_images=5)
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 138ms/step
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[23], line 13
#      10         plt.show()
#      12 # Mostrar 5 predicciones aleatorias
# ---> 13 show_predictions(model, validation_ds, num_images=5)
#
# Cell In[23], line 8, in show_predictions(model, dataset, num_images)
#       6 pred = model.predict(image)
#       7 plt.imshow(image[0].numpy().astype("uint8"))
# ----> 8 plt.title(f"Predicción: {class_names[np.argmax(pred)]}, Real: {class_names[label[0]]}")
#       9 plt.axis('off')
#      10 plt.show()
#
# IndexError: list index out of range

# %%
# Guardar el modelo en formato .keras
model.save("keras_plague_classifier.keras")
print("Modelo guardado en 'keras_plague_classifier.keras'.")

# %%
# Cargar el modelo guardado
from tensorflow.keras.models import load_model
loaded_model = load_model("keras_plague_classifier.keras")
print("Modelo cargado desde 'keras_plague_classifier.keras'.")

# %%
# Evaluar el modelo cargado para verificar
test_loss, test_acc = loaded_model.evaluate(test_ds)
print(f"Métricas de evaluación del modelo cargado: Pérdida = {test_loss}, Precisión = {test_acc}")
